# %% [markdown]
# <a href="https://colab.research.google.com/github/IvankoPilotOfHalychyna/Foundations_AI/blob/main/Tutorial9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial 9

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### Naive Bayes Algorithm
#
# The Naive Bayes algorithm is a classic probabilistic algorithm used primarily for classification. It is a model based on Bayes’ theorem with the assumption of feature independence. This means that for a given classified object, individual features (variables) are treated as independent, which significantly simplifies the computations.
#
# ## Bayes' Theorem
#
# Bayes’ theorem describes the relationship between conditional, prior, and posterior probabilities:
#
# $$
# P(C \mid X) = \frac{P(X \mid C) P(C)}{P(X)}
# $$
#
# where:
#
# - $ P(C \mid X) $ — the probability that an object belongs to class $ C $, given features $ X $ (posterior),
# - $ P(X \mid C) $ — the probability of observing features $ X $ if the object belongs to class $ C $ (likelihood),
# - $ P(C) $ — the prior probability that an object belongs to class $ C $,
# - $ P(X) $ — the probability of observing features $ X $ (often treated as a constant, ignored in classification).
#
# <br>
#
# ## Assumptions of Naive Bayes
#
# Naive Bayes assumes that the features are independent. This means that each feature is treated separately in the calculations, ignoring mutual dependencies between them. Thanks to this, the algorithm is very fast and efficient, although it does not always achieve the best results compared to more advanced models.
#
# ## Modeling in Naive Bayes
#
# To compute the probability that an object belongs to class $ C $, we use the following formula:
#
# $$
# P(C \mid X) = P(C) \prod_{i=1}^{n} P(x_i \mid C) \frac{1}{P(X)}
# $$
#
# $$
# \prod_{i=1}^{n} P(x_i \mid C) = P(x_1 \mid C) \cdot P(x_2 \mid C) \cdot \cdots \cdot P(x_i \mid C)
# $$
#
# $$
# P(C \mid X) = \frac {P(C) \cdot P(x_1 \mid C) \cdot P(x_2 \mid C) \cdot \cdots \cdot P(x_i \mid C)}{P(X)}
# $$
#
# <br>
#
# We may also ignore the denominator, because it is the same for all classes and does not affect the classification. Then:
#
# $$
# P(C \mid X) \propto P(C) \cdot P(x_1 \mid C) \cdot P(x_2 \mid C) \cdot \cdots \cdot P(x_i \mid C)
# $$
#
# where:
#
# - $ x_1, x_2, \dots, x_n $ are the features of the object $ X $,
# - $ P(x_i \mid C) $ is the probability of observing feature $ x_i $ given that the object belongs to class $ C $.
#
# In practice, the algorithm computes probabilities for each class and selects the class with the highest probability.
#
# ### Step by step:
#
# 1. Compute the prior probability $ P(C) $ for each class $ C $, i.e., the probability that a given object belongs to class $ C $:
#
# $$
# P(C) = \frac{\text{number of samples in class } C}{\text{total number of samples}}
# $$
#
# 2. Compute the conditional probabilities $ P(x_i \mid C) $ for each feature $ x_i $ and class $ C $. This can be done based on the frequency of the feature $ x_i $ in class $ C $.
#
# 3. Apply Bayes’ formula for each class $ C $ and choose the class for which $ P(C \mid X) $ is the highest.

# %% [markdown]
# ### Example of a Computational Task Using the Bayes Classifier
# Below is a dataset presenting object attributes and their classification.
#
# | Feature 1 (x1) | Feature 2 (x2) | Class (C) |
# |----------------|----------------|-----------|
# | Yes            | Yes            | A         |
# | Yes            | No             | A         |
# | No             | Yes            | B         |
# | No             | Yes            | A         |
# | Yes            | No             | B         |
#
# <br>
#
# ### Step 1: Compute the prior probabilities $P(A)$ and $P(B)$.
#
# $$
# P(A) = \frac{\text{number of samples in class A}}{\text{total number of samples}}
# $$
#
# $$
# P(B) = \frac{\text{number of samples in class B}}{\text{total number of samples}}
# $$
#
# <br>
#
# ### Step 2: Compute the conditional probabilities $P(x_1 \mid A)$, $P(x_1 \mid B)$, $P(x_2 \mid A)$, and $P(x_2 \mid B)$.
#
# For each feature, compute how frequently it appears in each class.
#
# <br>
#
# ### Step 3: Based on the calculated probabilities, compute $P(A \mid X)$ and $P(B \mid X)$, assuming we have an object with feature 1 = "Yes" and feature 2 = "No".
#
# $$ X = [Yes, No] $$
#
# The task is to determine to which class the new object will belong.

# %% [markdown]
# ### Calculating Probabilities Using Bayes' Formula
#
# ## 1. Compute the prior probabilities $ P(A) $ and $ P(B) $
#
# We have 5 samples in the dataset, of which:
# - 3 samples belong to class $ A $ (in the first, second, and fourth rows),
# - 2 samples belong to class $ B $ (in the third and fifth rows).
#
# We compute the prior probabilities for each class:
#
# $$
# P(A) = \frac{3}{5} = 0.6
# $$
#
# $$
# P(B) = \frac{2}{5} = 0.4
# $$
#
# <br>
#
# ## 2. Compute the conditional probabilities $ P(x_1 \mid A) $, $ P(x_1 \mid B) $, $ P(x_2 \mid A) $, and $ P(x_2 \mid B) $
#
# ### Feature 1 ($ x_1 $):
#
# $$
# P(x_1 = \text{Yes} \mid A) \quad \text{— How many times is feature 1 equal to "Yes" in class } A?
# $$
#
# In class $ A $ we have 3 samples, of which 2 have feature 1 equal to "Yes" (the first and second samples). Thus:
#
# $$
# P(x_1 = \text{Yes} \mid A) = \frac{2}{3}
# $$
#
# <br>
#
# $$
# P(x_1 = \text{Yes} \mid B) \quad \text{— How many times is feature 1 equal to "Yes" in class } B?
# $$
#
# In class $ B $ we have 2 samples, of which 1 has feature 1 equal to "Yes" (the third sample). Thus:
#
# $$
# P(x_1 = \text{Yes} \mid B) = \frac{1}{2}
# $$
#
# <br>
# <br>
#
# ### Feature 2 ($ x_2 $):
#
# $$
# P(x_2 = \text{Yes} \mid A) \quad \text{— How many times is feature 2 equal to "Yes" in class } A?
# $$
#
# In class $ A $ we have 3 samples, of which 2 have feature 2 equal to "Yes" (the first and fourth samples). Thus:
#
# $$
# P(x_2 = \text{Yes} \mid A) = \frac{2}{3}
# $$
#
# $$
# P(x_2 = \text{Yes} \mid B) \quad \text{— How many times is feature 2 equal to "Yes" in class } B?
# $$
#
# In class $ B $ we have 2 samples, of which 1 has feature 2 equal to "Yes" (the third sample). Thus:
#
# $$
# P(x_2 = \text{Yes} \mid B) = \frac{1}{2}
# $$
#
# <br>
# <br>
#
# ## 3. Compute $ P(A \mid X) $ and $ P(B \mid X) $
#
# We have a new object with the following features:
# - Feature 1 = "Yes"
# - Feature 2 = "No"
#
# Thus we compute $ P(x_1 = \text{Yes}, x_2 = \text{No}) $.
#
# ### Calculating $ P(A \mid X) $:
#
# Let us use Bayes’ formula for class $ A $:
#
# $$
# P(A \mid X) \propto P(A) \cdot P(x_1 = \text{Yes} \mid A) \cdot P(x_2 = \text{No} \mid A)
# $$
#
# $$
# P(x_1 = \text{Yes} \mid A) = \frac{2}{3}, \quad P(x_2 = \text{No} \mid A) = 1 - \frac{2}{3} = \frac{1}{3}
# $$
#
# $$
# P(A \mid X) \propto 0.6 \cdot \frac{2}{3} \cdot \frac{1}{3} = 0.6 \cdot \frac{2}{9} = \frac{1.2}{9} = \frac{2}{15}
# $$
#
# ### Calculating $ P(B \mid X) $:
#
# Use Bayes’ formula for class $ B $:
#
# $$
# P(B \mid X) \propto P(B) \cdot P(x_1 = \text{Yes} \mid B) \cdot P(x_2 = \text{No} \mid B)
# $$
#
# $$
# P(x_1 = \text{Yes} \mid B) = \frac{1}{2}, \quad P(x_2 = \text{No} \mid B) = 1 - \frac{1}{2} = \frac{1}{2}
# $$
#
# $$
# P(B \mid X) \propto 0.4 \cdot \frac{1}{2} \cdot \frac{1}{2} = 0.4 \cdot \frac{1}{4} = \frac{0.4}{4} = \frac{1}{10}
# $$
#
# ## 4. Class Selection
#
# Comparing the values of $ P(A \mid X) $ and $ P(B \mid X) $, we get:
#
# $$
# P(A \mid X) = \frac{2}{15}, \quad P(B \mid X) = \frac{1}{10} = \frac{1.5}{15}
# $$
#
# Since $ P(B \mid X) > P(A \mid X) $, the object will be assigned to class $ B $.

# %% [markdown]
# ### Example of Using the Bayes Classifier in Python Code

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

iris = load_iris()
X = iris.data
y = iris.target

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = GaussianNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.4f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9778
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       1.00      0.92      0.96        13
#            2       0.93      1.00      0.96        13
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.97      0.97        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ## Task 1
# For the table below, classify the vector $ X = [No, Yes] $ using the Naive Bayes classifier.
#
# | Feature 1 (x1) | Feature 2 (x2) | Class (C) |
# |----------------|----------------|-----------|
# | No             | Yes            | C         |
# | Yes            | No             | A         |
# | No             | Yes            | D         |
# | Yes            | No             | A         |
# | No             | No             | D         |
# | No             | Yes            | C         |

# %% [markdown]
# # Task 1 solution

# %%
import pandas as pd

# Data provided in the table
data = {
    'Feature 1': ['No', 'Yes', 'No', 'Yes', 'No', 'No'],
    'Feature 2': ['Yes', 'No', 'Yes', 'No', 'No', 'Yes'],
    'Class': ['C', 'A', 'D', 'A', 'D', 'C']
}
df = pd.DataFrame(data)

print("Original Dataset:")
print(df)
print("\n")

# New vector to classify
X_new = {'Feature 1': 'No', 'Feature 2': 'Yes'}

# 1. Calculate Prior Probabilities P(C)
class_counts = df['Class'].value_counts()
total_samples = len(df)
prior_probabilities = class_counts / total_samples

print("Prior Probabilities (P(C)):")
print(prior_probabilities)
print("\n")

# 2. Calculate Conditional Probabilities P(Feature_value | Class)
conditional_probabilities = {}
for feature in ['Feature 1', 'Feature 2']:
    conditional_probabilities[feature] = {}
    for cls in df['Class'].unique():
        df_class = df[df['Class'] == cls]
        feature_value_counts = df_class[feature].value_counts()
        # Add Laplace smoothing to handle zero probabilities, although for this specific dataset it won't change the result due to zero P(A|X) and P(D|X).
        # Adding 1 to numerator and number of unique feature values to denominator.
        # This makes it robust to cases where a feature value doesn't appear in a class.
        # For this specific task, let's keep it without smoothing first to match manual calculation exactly, then mention smoothing importance.

        # Using direct counts for this problem as per manual calculation example structure.
        cond_probs = feature_value_counts / len(df_class)
        conditional_probabilities[feature][cls] = cond_probs.to_dict()

print("Conditional Probabilities (P(Feature_value | Class)):")
for feature, classes in conditional_probabilities.items():
    print(f"  {feature}:")
    for cls, probs in classes.items():
        print(f"    Class {cls}: {probs}")
print("\n")

# 3. Classify the new vector X = [No, Yes]
posterior_scores = {}
for cls in df['Class'].unique():
    score = prior_probabilities[cls]

    # P(x1=No | Class)
    feature1_val = X_new['Feature 1']
    prob_feature1_given_class = conditional_probabilities['Feature 1'][cls].get(feature1_val, 0) # Use .get with 0 for unseen values

    # P(x2=Yes | Class)
    feature2_val = X_new['Feature 2']
    prob_feature2_given_class = conditional_probabilities['Feature 2'][cls].get(feature2_val, 0) # Use .get with 0 for unseen values

    score *= prob_feature1_given_class * prob_feature2_given_class
    posterior_scores[cls] = score

print(f"New vector X: {X_new}")
print("Posterior Scores (P(C) * P(x1 | C) * P(x2 | C)):")
print(posterior_scores)

# Select the class with the highest posterior score
predicted_class = max(posterior_scores, key=posterior_scores.get)

print(f"\nThe classified class for X = {X_new} is: {predicted_class}")
# Out:
# Original Dataset:
#   Feature 1 Feature 2 Class
# 0        No       Yes     C
# 1       Yes        No     A
# 2        No       Yes     D
# 3       Yes        No     A
# 4        No        No     D
# 5        No       Yes     C
#
#
# Prior Probabilities (P(C)):
# Class
# C    0.333333
# A    0.333333
# D    0.333333
# Name: count, dtype: float64
#
#
# Conditional Probabilities (P(Feature_value | Class)):
#   Feature 1:
#     Class C: {'No': 1.0}
#     Class A: {'Yes': 1.0}
#     Class D: {'No': 1.0}
#   Feature 2:
#     Class C: {'Yes': 1.0}
#     Class A: {'No': 1.0}
#     Class D: {'Yes': 0.5, 'No': 0.5}
#
#
# New vector X: {'Feature 1': 'No', 'Feature 2': 'Yes'}
# Posterior Scores (P(C) * P(x1 | C) * P(x2 | C)):
# {'C': np.float64(0.3333333333333333), 'A': np.float64(0.0), 'D': np.float64(0.16666666666666666)}
#
# The classified class for X = {'Feature 1': 'No', 'Feature 2': 'Yes'} is: C

# %% [markdown]
# ## Task 2
# For the `load_breast_cancer` dataset from the `sklearn.datasets` module, perform DEA analysis and classification using the `Naive Bayes` classifier. Remember to scale the data.
#
# <br>
#
# Example of loading the data:
#
# ```
# from sklearn.datasets import load_breast_cancer
#
# data = load_breast_cancer()
# X = data.data
# y = data.target
# ```

# %% [markdown]
# # Task 2 solution

# %%
from sklearn.datasets import load_breast_cancer

# Load the breast_cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target

print("Breast Cancer dataset loaded successfully.")
print(f"Shape of features (X): {X.shape}")
print(f"Shape of target (y): {y.shape}")
# Out:
# Breast Cancer dataset loaded successfully.
# Shape of features (X): (569, 30)
# Shape of target (y): (569,)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
import pandas as pd

# 1. Convert the feature data X into a pandas DataFrame
df_X = pd.DataFrame(X, columns=data.feature_names)

print("### Feature DataFrame (df_X) ###\n")

# 2. Print the first 5 rows of df_X
print("First 5 rows of df_X:")
print(df_X.head())
print("\n")

# 3. Display a concise summary of the df_X DataFrame
print("Concise summary of df_X:")
df_X.info()
print("\n")

# 4. Generate descriptive statistics for df_X
print("Descriptive statistics for df_X:")
print(df_X.describe())
print("\n")

# 5. Print the target names
print("Target names:")
print(data.target_names)
print("\n")

# 6. Calculate and print the distribution of the target variable y
print("Distribution of target variable (y):")
# Convert y to a Series for easier value counting and use target names for labels
df_y = pd.Series(y).map(lambda x: data.target_names[x])
print(df_y.value_counts())
# Out:
# ### Feature DataFrame (df_X) ###
#
# First 5 rows of df_X:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]
#
#
# Concise summary of df_X:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
# dtypes: float64(30)
# memory usage: 133.5 KB
#
#
# Descriptive statistics for df_X:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        mean symmetry  mean fractal dimension  ...  worst radius  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        worst texture  worst perimeter   worst area  worst smoothness  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        worst compactness  worst concavity  worst concave points  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        worst symmetry  worst fractal dimension
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]
#
#
# Target names:
# ['malignant' 'benign']
#
#
# Distribution of target variable (y):
# benign       357
# malignant    212
# Name: count, dtype: int64

# %% [markdown]
# ## Scale Data

# %%
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Scale the features (X)
X_scaled = scaler.fit_transform(X)

print("Features scaled successfully. First 5 rows of scaled data:")
print(X_scaled[:5])
# Out:
# Features scaled successfully. First 5 rows of scaled data:
# [[ 1.09706398e+00 -2.07333501e+00  1.26993369e+00  9.84374905e-01
#    1.56846633e+00  3.28351467e+00  2.65287398e+00  2.53247522e+00
#    2.21751501e+00  2.25574689e+00  2.48973393e+00 -5.65265059e-01
#    2.83303087e+00  2.48757756e+00 -2.14001647e-01  1.31686157e+00
#    7.24026158e-01  6.60819941e-01  1.14875667e+00  9.07083081e-01
#    1.88668963e+00 -1.35929347e+00  2.30360062e+00  2.00123749e+00
#    1.30768627e+00  2.61666502e+00  2.10952635e+00  2.29607613e+00
#    2.75062224e+00  1.93701461e+00]
#  [ 1.82982061e+00 -3.53632408e-01  1.68595471e+00  1.90870825e+00
#   -8.26962447e-01 -4.87071673e-01 -2.38458552e-02  5.48144156e-01
#    1.39236330e-03 -8.68652457e-01  4.99254601e-01 -8.76243603e-01
#    2.63326966e-01  7.42401948e-01 -6.05350847e-01 -6.92926270e-01
#   -4.40780058e-01  2.60162067e-01 -8.05450380e-01 -9.94437403e-02
#    1.80592744e+00 -3.69203222e-01  1.53512599e+00  1.89048899e+00
#   -3.75611957e-01 -4.30444219e-01 -1.46748968e-01  1.08708430e+00
#   -2.43889668e-01  2.81189987e-01]
#  [ 1.57988811e+00  4.56186952e-01  1.56650313e+00  1.55888363e+00
#    9.42210440e-01  1.05292554e+00  1.36347845e+00  2.03723076e+00
#    9.39684817e-01 -3.98007910e-01  1.22867595e+00 -7.80083377e-01
#    8.50928301e-01  1.18133606e+00 -2.97005012e-01  8.14973504e-01
#    2.13076435e-01  1.42482747e+00  2.37035535e-01  2.93559404e-01
#    1.51187025e+00 -2.39743838e-02  1.34747521e+00  1.45628455e+00
#    5.27407405e-01  1.08293217e+00  8.54973944e-01  1.95500035e+00
#    1.15225500e+00  2.01391209e-01]
#  [-7.68909287e-01  2.53732112e-01 -5.92687167e-01 -7.64463792e-01
#    3.28355348e+00  3.40290899e+00  1.91589718e+00  1.45170736e+00
#    2.86738293e+00  4.91091929e+00  3.26373441e-01 -1.10409044e-01
#    2.86593405e-01 -2.88378148e-01  6.89701660e-01  2.74428041e+00
#    8.19518384e-01  1.11500701e+00  4.73268037e+00  2.04751088e+00
#   -2.81464464e-01  1.33984094e-01 -2.49939304e-01 -5.50021228e-01
#    3.39427470e+00  3.89339743e+00  1.98958826e+00  2.17578601e+00
#    6.04604135e+00  4.93501034e+00]
#  [ 1.75029663e+00 -1.15181643e+00  1.77657315e+00  1.82622928e+00
#    2.80371830e-01  5.39340452e-01  1.37101143e+00  1.42849277e+00
#   -9.56046689e-03 -5.62449981e-01  1.27054278e+00 -7.90243702e-01
#    1.27318941e+00  1.19035676e+00  1.48306716e+00 -4.85198799e-02
#    8.28470780e-01  1.14420474e+00 -3.61092272e-01  4.99328134e-01
#    1.29857524e+00 -1.46677038e+00  1.33853946e+00  1.22072425e+00
#    2.20556166e-01 -3.13394511e-01  6.13178758e-01  7.29259257e-01
#   -8.68352984e-01 -3.97099619e-01]]

# %% [markdown]
# ## Split Dataset

# %%
from sklearn.model_selection import train_test_split

# Split the scaled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

print("Data split into training and testing sets successfully.")
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# Data split into training and testing sets successfully.
# X_train shape: (398, 30)
# X_test shape: (171, 30)
# y_train shape: (398,)
# y_test shape: (171,)

# %% [markdown]
# ## Train a Naive Bayes classifier

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score, classification_report

# Initialize the Naive Bayes classifier (Gaussian Naive Bayes is suitable for continuous data)
model = GaussianNB()

# Train the model on the scaled training data
model.fit(X_train, y_train)

# Make predictions on the scaled test data
y_pred = model.predict(X_test)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
# Model Accuracy: 0.9357
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    malignant       0.92      0.90      0.91        63
#       benign       0.94      0.95      0.95       108
#
#     accuracy                           0.94       171
#    macro avg       0.93      0.93      0.93       171
# weighted avg       0.94      0.94      0.94       171

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
# *   The `breast_cancer` dataset was successfully loaded, containing 569 samples and 30 features.
# *   Exploratory Data Analysis revealed no missing values across the 30 features, and the dataset included both 'malignant' and 'benign' target classes.
# *   The target variable distribution showed 357 'benign' cases and 212 'malignant' cases.
# *   Features were successfully scaled using `StandardScaler`.
# *   The data was split into training (398 samples) and testing (171 samples) sets, with a test size of 30%.
# *   A Gaussian Naive Bayes classifier was trained and achieved an accuracy of 0.9357 on the test set.
# *   The model demonstrated good performance for both classes, with a precision of 0.92, recall of 0.90, and F1-score of 0.91 for 'malignant' cases, and precision of 0.94, recall of 0.95, and F1-score of 0.95 for 'benign' cases.
